# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

# %%
# https://www.zenrows.com/blog/scraping-javascript-rendered-web-pages#installing-the-requirements
data = []
options = Options() 
options.headless = True
driver = webdriver.Chrome(options=options, executable_path=r"C:\Users\pc\Desktop\pypypy\web_scraping\chromedriver.exe")
driver.get("http://quotes.toscrape.com/random")
for i in range(10):
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, "lxml")
    item = soup.find("div", class_="quote")
    tags = item.find_all("a", class_="tag")
    data.append([
        item.find("small").text,
        item.find("span", class_="text").text,
        [x.text for x in tags]
    ])
    driver.refresh()
driver.close()

# %%
df = pd.DataFrame(data, columns = ["Name", "Quote", "Tags"])
df
# Out:
#                    Name                                              Quote  \
# 0         James Baldwin  “Love does not begin and end the way we seem t...
# 1  Alexandre Dumas fils  “The difference between genius and stupidity i...
# 2          J.K. Rowling  “Remember, if the time should come when you ha...
# 3         George Carlin  “The reason I talk to myself is because I’m th...
# 4           W.C. Fields  “I am free of all prejudice. I hate everyone e...
# 5        Marilyn Monroe  “I am good, but not an angel. I do sin, but I ...
# 6   George Bernard Shaw  “Life isn't about finding yourself. Life is ab...
# 7    George R.R. Martin  “... a mind needs books as a sword needs a whe...
# 8            Bob Marley  “One good thing about music, when it hits you,...
# 9             Dr. Seuss  “I have heard there are troubles of more than ...
#
#                                                 Tags
# 0                                             [love]
# ...
